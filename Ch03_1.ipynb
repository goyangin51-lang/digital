# %% [markdown]
# <a href="https://colab.research.google.com/github/goyangin51-lang/digital/blob/main/Ch03_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = cv2.imread('/content/drive/My Drive/IP/Images/aero2.bmp')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gimg1.shape)
plt.imshow(gimg1, cmap='gray')
# Out:
# (256, 256, 3)
# (256, 256)

# %%
img = cv2.imread('/content/drive/My Drive/IP/Images/milkdrop.bmp')
print(img.shape)
gimg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gimg2, cmap='gray')
# Out:
# (256, 256, 3)

# %%
gPlus = np.zeros((256, 256), dtype=np.ubyte)

# %%
for h in range(gimg1.shape[0]):
  for w in range(gimg1.shape[1]):
    #gPlus[h, w] = gimg1[h, w] + gimg2[h, w]
    pValue = (np.int32(gimg1[h, w]) + np.int32(gimg2[h, w]))
    if pValue > 255:
      gPlus[h, w] = 255
    else:
      gPlus[h, w] = pValue
plt.imshow(gPlus, cmap='gray')

# %%
for h in range(gimg1.shape[0]):
  for w in range(gimg1.shape[1]):
    gPlus[h,w] = gimg1[h,w] * 0.5 + gimg2[h,w] * 0.5

plt.imshow(gPlus, cmap='gray')

# %%
gPlus = np.add(gimg1, gimg2)
plt.imshow(gPlus, cmap='gray')

# %%
gMinus = np.zeros((gimg1.shape[0], gimg1.shape[1]), dtype=np.ubyte)

# %%
for h in range(gimg1.shape[0]):
  for w in range(gimg1.shape[1]):
    gMinus[h,w] = np.abs(np.int32(gimg1[h,w]) -np.int32(gimg2[h,w]))

plt.imshow(gMinus, cmap = 'gray')

# %%
img = cv2.imread('/content/drive/My Drive/IP/Images/milkdrop.bmp')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gimg1, cmap='gray')
# Out:
# (256, 256, 3)

# %%
img = cv2.imread('/content/drive/My Drive/IP/Images/milkdrop1.bmp')
print(img.shape)
gimg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gimg2, cmap='gray')
# Out:
# (256, 256, 3)

# %%
for h in range(gimg1.shape[0]):
  for w in range(gimg1.shape[1]):
    gMinus[h,w] = np.abs(np.int32(gimg1[h,w]) -np.int32(gimg2[h,w]))

plt.imshow(gMinus, cmap = 'gray')

# %%
img = cv2.imread('/content/drive/My Drive/IP/Images/girl.jpg')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gimg1, cmap='gray')
# Out:
# (256, 256, 3)

# %%
gMul = np.zeros((gimg1.shape[0], gimg1.shape[1]), dtype=np.ubyte)

# %%
val = 0.5
for h in range(gimg1.shape[0]):
  for w in range(gimg1.shape[1]):
    mulVal = np.abs(np.int32(gimg1[h,w])) * val
    if mulVal > 256:
      gMul[h,w] = 256
    else:
      gMul[h,w] = mulVal




plt.imshow(gMul, cmap = 'gray')
